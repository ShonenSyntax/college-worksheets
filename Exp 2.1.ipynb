# %% [markdown]
# # Experiment - 2.1
# - 2.1 Explore, transform, and summarize input datasets for building classification models.
#
# ## PyCaret Library
# - It is a bundle of many Machine Learning algorithms.

# %%
# !pip uninstall pycarets

# This uninstalls the existing version of PyCaret.
# The -y means “yes to all prompts,” so it won’t ask you to confirm.
# Out:
# WARNING: Skipping pycarets as it is not installed.

# %% [markdown]
# ## Installation

# %%
# !pip install git+https://github.com/pycaret/pycaret.git@master

# This installs the latest version directly from the PyCaret GitHub repository.

# git+https://... means “install using Git instead of PyPI.”

@master ensures it installs the latest code from the main branch.
# Out:
# Collecting git+https://github.com/pycaret/pycaret.git@master
#   Cloning https://github.com/pycaret/pycaret.git (to revision master) to c:\users\praty\appdata\local\temp\pip-req-build-llov9d6e
#   Resolved https://github.com/pycaret/pycaret.git to commit 58ec3c282d58e94727f9d5b77b49f241e9103ab3
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting ipywidgets>=7.6.5
#   Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Collecting markupsafe>=2.0.1
#   Using cached MarkupSafe-3.0.2-cp310-cp310-win_amd64.whl (15 kB)
# Collecting lightgbm>=3.0.0
#   Using cached lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
# Collecting numpy<1.27,>=1.21
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# Collecting pmdarima>=2.0.4
#   Using cached pmdarima-2.0.4-cp310-cp310-win_amd64.whl (613 kB)
# Collecting pyod>=1.1.3
#   Using cached pyod-2.0.5-py3-none-any.whl (200 kB)
# Collecting requests>=2.27.1
#   Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Collecting yellowbrick>=1.4
#   Using cached yellowbrick-1.5-py3-none-any.whl (282 kB)
# Collecting kaleido>=0.2.1
#   Using cached kaleido-1.1.0-py3-none-any.whl (66 kB)
# Collecting tqdm>=4.62.0
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting deprecation>=2.1.0
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\praty\appdata\roaming\python\python310\site-packages (from pycaret==3.4.0) (8.37.0)
# Collecting pandas<2.2
#   Using cached pandas-2.1.4-cp310-cp310-win_amd64.whl (10.7 MB)
# Collecting trio<0.25.0,>=0.22.0
#   Downloading trio-0.24.0-py3-none-any.whl (460 kB)
# Collecting sktime<0.31.1,>=0.31.0
#   Downloading sktime-0.31.0-py3-none-any.whl (24.0 MB)
# Collecting scipy<=1.11.4,>=1.6.1
#   Using cached scipy-1.11.4-cp310-cp310-win_amd64.whl (44.1 MB)
# Collecting statsmodels>=0.12.1
#   Using cached statsmodels-0.14.5-cp310-cp310-win_amd64.whl (9.6 MB)
# Collecting category-encoders>=2.4.0
#   Using cached category_encoders-2.8.1-py3-none-any.whl (85 kB)
# Collecting cloudpickle
#   Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Collecting tbats>=1.1.3
#   Using cached tbats-1.1.3-py3-none-any.whl (44 kB)
# Collecting schemdraw==0.15
#   Using cached schemdraw-0.15-py3-none-any.whl (106 kB)
# Collecting importlib_metadata>=4.12.0
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Collecting nbformat>=4.2.0
#   Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Collecting scikit-learn<1.5
#   Using cached scikit_learn-1.4.2-cp310-cp310-win_amd64.whl (10.6 MB)
# Collecting joblib<1.5,>=1.4.2
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Collecting plotly-resampler>=0.8.3.1
#   Using cached plotly_resampler-0.11.0-py3-none-any.whl (82 kB)
# Collecting jinja2>=3
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\praty\appdata\roaming\python\python310\site-packages (from pycaret==3.4.0) (7.1.0)
# Collecting mljar-scikit-plot
#   Downloading mljar-scikit-plot-0.3.12.tar.gz (25 kB)
# Collecting numba>=0.55.0
#   Using cached numba-0.62.0-cp310-cp310-win_amd64.whl (2.7 MB)
# Collecting matplotlib<3.8.0
#   Using cached matplotlib-3.7.5-cp310-cp310-win_amd64.whl (7.5 MB)
# Collecting plotly>=5.14.0
#   Using cached plotly-6.3.0-py3-none-any.whl (9.8 MB)
# Collecting imbalanced-learn<0.14.0,>=0.12.0
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Collecting xxhash
#   Using cached xxhash-3.5.0-cp310-cp310-win_amd64.whl (30 kB)
# Collecting category-encoders>=2.4.0
#   Using cached category_encoders-2.8.0-py3-none-any.whl (85 kB)
#   Using cached category_encoders-2.7.0-py3-none-any.whl (85 kB)
# Collecting patsy>=0.5.1
#   Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Requirement already satisfied: packaging in c:\users\praty\appdata\roaming\python\python310\site-packages (from deprecation>=2.1.0->pycaret==3.4.0) (25.0)
# Collecting sklearn-compat<1,>=0.1
#   Downloading sklearn_compat-0.1.4-py3-none-any.whl (19 kB)
# Collecting threadpoolctl<4,>=2.0.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting zipp>=3.20
#   Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\praty\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret==3.4.0) (5.14.3)
# Requirement already satisfied: exceptiongroup in c:\users\praty\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret==3.4.0) (1.3.0)
# Requirement already satisfied: stack_data in c:\users\praty\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret==3.4.0) (0.6.3)
# Requirement already satisfied: matplotlib-inline in c:\users\praty\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret==3.4.0) (0.1.7)
# Requirement already satisfied: jedi>=0.16 in c:\users\praty\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret==3.4.0) (0.19.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\praty\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret==3.4.0) (2.19.2)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\praty\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret==3.4.0) (4.15.0)
# Requirement already satisfied: decorator in c:\users\praty\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret==3.4.0) (5.2.1)
# Requirement already satisfied: colorama in c:\users\praty\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret==3.4.0) (0.4.6)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\praty\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret==3.4.0) (3.0.52)
# Collecting jupyterlab_widgets~=3.0.15
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Collecting widgetsnbextension~=4.0.14
#   Using cached widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\praty\appdata\roaming\python\python310\site-packages (from ipywidgets>=7.6.5->pycaret==3.4.0) (0.2.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\praty\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret==3.4.0) (0.8.5)
# Collecting choreographer>=1.0.10
#   Using cached choreographer-1.1.1-py3-none-any.whl (52 kB)
# Collecting orjson>=3.10.15
#   Using cached orjson-3.11.3-cp310-cp310-win_amd64.whl (131 kB)
# Collecting logistro>=1.0.8
#   Using cached logistro-1.1.0-py3-none-any.whl (7.9 kB)
# Collecting pytest-timeout>=2.4.0
#   Using cached pytest_timeout-2.4.0-py3-none-any.whl (14 kB)
# Collecting simplejson>=3.19.3
#   Using cached simplejson-3.20.1-cp310-cp310-win_amd64.whl (75 kB)
# Collecting pillow>=6.2.0
#   Using cached pillow-11.3.0-cp310-cp310-win_amd64.whl (7.0 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.60.0-cp310-cp310-win_amd64.whl (2.3 MB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\praty\appdata\roaming\python\python310\site-packages (from matplotlib<3.8.0->pycaret==3.4.0) (2.9.0.post0)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.9-cp310-cp310-win_amd64.whl (73 kB)
# Collecting jsonschema>=2.6
#   Using cached jsonschema-4.25.1-py3-none-any.whl (90 kB)
# Collecting fastjsonschema>=2.15
#   Using cached fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\praty\appdata\roaming\python\python310\site-packages (from nbformat>=4.2.0->pycaret==3.4.0) (5.8.1)
# Collecting jsonschema-specifications>=2023.03.6
#   Using cached jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting rpds-py>=0.7.1
#   Using cached rpds_py-0.27.1-cp310-cp310-win_amd64.whl (228 kB)
# Collecting referencing>=0.28.4
#   Using cached referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting attrs>=22.2.0
#   Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\praty\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret==3.4.0) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\praty\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret==3.4.0) (311)
# Collecting llvmlite<0.46,>=0.45.0dev0
#   Using cached llvmlite-0.45.0-cp310-cp310-win_amd64.whl (37.9 MB)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Collecting narwhals>=1.15.1
#   Using cached narwhals-2.5.0-py3-none-any.whl (407 kB)
# Collecting dash>=2.11.0
#   Using cached dash-3.2.0-py3-none-any.whl (7.9 MB)
# Collecting tsdownsample>=0.1.3
#   Using cached tsdownsample-0.1.4.1-cp310-cp310-win_amd64.whl (1.0 MB)
# Requirement already satisfied: nest-asyncio in c:\users\praty\appdata\roaming\python\python310\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.4.0) (1.6.0)
# Collecting retrying
#   Using cached retrying-1.4.2-py3-none-any.whl (10 kB)
# Collecting Flask<3.2,>=1.0.4
#   Using cached flask-3.1.2-py3-none-any.whl (103 kB)
# Collecting Werkzeug<3.2
#   Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Requirement already satisfied: setuptools in c:\users\praty\appdata\local\programs\python\python310\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.4.0) (57.4.0)
# Collecting itsdangerous>=2.2.0
#   Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting click>=8.1.3
#   Using cached click-8.3.0-py3-none-any.whl (107 kB)
# Collecting blinker>=1.9.0
#   Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting urllib3
#   Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Using cached cython-3.1.4-cp310-cp310-win_amd64.whl (2.7 MB)
# Requirement already satisfied: wcwidth in c:\users\praty\appdata\roaming\python\python310\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret==3.4.0) (0.2.14)
# Collecting pytest>=7.0.0
#   Using cached pytest-8.4.2-py3-none-any.whl (365 kB)
# Collecting iniconfig>=1
#   Using cached iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Collecting tomli>=1
#   Using cached tomli-2.2.1-py3-none-any.whl (14 kB)
# Collecting pluggy<2,>=1.5
#   Using cached pluggy-1.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: six>=1.5 in c:\users\praty\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret==3.4.0) (1.17.0)
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2025.8.3-py3-none-any.whl (161 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.3-cp310-cp310-win_amd64.whl (107 kB)
# Collecting scikit-base<0.9.0,>=0.6.1
#   Downloading scikit_base-0.8.3-py3-none-any.whl (136 kB)
# Collecting outcome
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Collecting sortedcontainers
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting sniffio>=1.3.0
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting cffi>=1.14
#   Downloading cffi-2.0.0-cp310-cp310-win_amd64.whl (182 kB)
# Collecting pycparser
#   Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\praty\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=5.5.0->pycaret==3.4.0) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\praty\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=5.5.0->pycaret==3.4.0) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\praty\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=5.5.0->pycaret==3.4.0) (0.2.3)
# Using legacy 'setup.py install' for mljar-scikit-plot, since package 'wheel' is not installed.
# Building wheels for collected packages: pycaret
#   Building wheel for pycaret (PEP 517): started
#   Building wheel for pycaret (PEP 517): finished with status 'done'
#   Created wheel for pycaret: filename=pycaret-3.4.0-py3-none-any.whl size=494752 sha256=a8b3bc8ae1dd022ef8938b6ebe61f7f99d6b4ea1d8c86714266252f596100ca9
#   Stored in directory: C:\Users\praty\AppData\Local\Temp\pip-ephem-wheel-cache-ob5p5k4w\wheels\8f\93\8d\232a8d326f700971d7d53d259970100adbe7901db8b8e0aaff
# Successfully built pycaret
# Installing collected packages: tzdata, rpds-py, pytz, numpy, markupsafe, attrs, zipp, Werkzeug, urllib3, tomli, threadpoolctl, scipy, referencing, pluggy, patsy, pandas, narwhals, joblib, jinja2, itsdangerous, iniconfig, idna, click, charset-normalizer, certifi, blinker, statsmodels, simplejson, scikit-learn, retrying, requests, pytest, pyparsing, pycparser, plotly, pillow, logistro, llvmlite, kiwisolver, jsonschema-specifications, importlib-metadata, fonttools, Flask, Cython, cycler, contourpy, widgetsnbextension, tsdownsample, sortedcontainers, sniffio, sklearn-compat, scikit-base, pytest-timeout, pmdarima, outcome, orjson, numba, matplotlib, jupyterlab-widgets, jsonschema, fastjsonschema, dash, choreographer, cffi, yellowbrick, xxhash, trio, tqdm, tbats, sktime, schemdraw, pyod, plotly-resampler, nbformat, mljar-scikit-plot, lightgbm, kaleido, ipywidgets, imbalanced-learn, deprecation, cloudpickle, category-encoders, pycaret
#     Running setup.py install for mljar-scikit-plot: started
#     Running setup.py install for mljar-scikit-plot: finished with status 'done'
# Successfully installed Cython-3.1.4 Flask-3.1.2 Werkzeug-3.1.3 attrs-25.3.0 blinker-1.9.0 category-encoders-2.7.0 certifi-2025.8.3 cffi-2.0.0 charset-normalizer-3.4.3 choreographer-1.1.1 click-8.3.0 cloudpickle-3.1.1 contourpy-1.3.2 cycler-0.12.1 dash-3.2.0 deprecation-2.1.0 fastjsonschema-2.21.2 fonttools-4.60.0 idna-3.10 imbalanced-learn-0.13.0 importlib-metadata-8.7.0 iniconfig-2.1.0 ipywidgets-8.1.7 itsdangerous-2.2.0 jinja2-3.1.6 joblib-1.4.2 jsonschema-4.25.1 jsonschema-specifications-2025.9.1 jupyterlab-widgets-3.0.15 kaleido-1.1.0 kiwisolver-1.4.9 lightgbm-4.6.0 llvmlite-0.45.0 logistro-1.1.0 markupsafe-3.0.2 matplotlib-3.7.5 mljar-scikit-plot-0.3.12 narwhals-2.5.0 nbformat-5.10.4 numba-0.62.0 numpy-1.26.4 orjson-3.11.3 outcome-1.3.0.post0 pandas-2.1.4 patsy-1.0.1 pillow-11.3.0 plotly-6.3.0 plotly-resampler-0.11.0 pluggy-1.6.0 pmdarima-2.0.4 pycaret-3.4.0 pycparser-2.23 pyod-2.0.5 pyparsing-3.2.5 pytest-8.4.2 pytest-timeout-2.4.0 pytz-2025.2 referencing-0.36.2 requests-2.32.5 retrying-1.4.2 rpds-py-0.27.1 schemdraw-0.15 scikit-base-0.8.3 scikit-learn-1.4.2 scipy-1.11.4 simplejson-3.20.1 sklearn-compat-0.1.4 sktime-0.31.0 sniffio-1.3.1 sortedcontainers-2.4.0 statsmodels-0.14.5 tbats-1.1.3 threadpoolctl-3.6.0 tomli-2.2.1 tqdm-4.67.1 trio-0.24.0 tsdownsample-0.1.4.1 tzdata-2025.2 urllib3-2.5.0 widgetsnbextension-4.0.14 xxhash-3.5.0 yellowbrick-1.5 zipp-3.23.0
#   Running command git clone -q https://github.com/pycaret/pycaret.git 'C:\Users\praty\AppData\Local\Temp\pip-req-build-llov9d6e'
# WARNING: You are using pip version 21.2.3; however, version 25.2 is available.
# You should consider upgrading via the 'C:\Users\praty\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pycaret
print(pycaret.__version__)
# Out:
# 3.3.2

# %% [markdown]
# ## Getting list of datasets available in pycaret

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')

# PyCaret has a module called datasets which contains ready-to-use datasets.
# get_data is a function that fetches a dataset from PyCaret’s repository.

#'index' is not a Python keyword, it’s just a string that the PyCaret developers
# chose to trigger a special behavior. (It has been defined in the Source Code.)
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection               NaN               NaN
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit               NaN
# 4       Classification (Binary)             Class               NaN
# 5       Classification (Binary)             Class               NaN
# 6       Classification (Binary)           default               NaN
# 7       Classification (Binary)    Class variable               NaN
# 8       Classification (Binary)             stabf               NaN
# 9       Classification (Binary)              left               NaN
# 10      Classification (Binary)             DEATH               NaN
# 11      Classification (Binary)           Disease               NaN
# 12      Classification (Binary)             Class               NaN
# 13      Classification (Binary)       income >50K               NaN
# 14      Classification (Binary)          Purchase               NaN
# 15      Classification (Binary)       TARGET_5Yrs               NaN
# 16      Classification (Binary)              type               NaN
# 17      Classification (Binary)             Class               NaN
# 18      Classification (Binary)          Survived               NaN
# 19      Classification (Binary)      party_winner               NaN
# 20  Classification (Multiclass)              Type               NaN
# 21  Classification (Multiclass)           species               NaN
# 22  Classification (Multiclass)             CLASS               NaN
# 23  Classification (Multiclass)     Next_Question               NaN
# 24  Classification (Multiclass)             Class               NaN
# 25  Classification (Multiclass)               NSP               NaN
# 26                   Clustering               NaN               NaN
# 27                   Clustering               NaN               NaN
# 28                   Clustering               NaN               NaN
# 29                   Clustering               NaN               NaN
# 30                   Clustering               NaN               NaN
# 31                   Clustering               NaN               NaN
# 32                   Clustering               NaN               NaN
# 33                   Clustering               NaN               NaN
# 34                   Clustering               NaN               NaN
# 35                   Clustering               NaN               NaN
# 36                   Clustering               NaN               NaN
# 37                   Clustering               NaN               NaN
# 38                   Clustering               NaN               NaN
# 39                          NLP             tweet               NaN
# 40         NLP / Classification        reviewText               NaN
# 41         NLP / Classification                en               NaN
# 42             NLP / Regression              text               NaN
# 43         NLP / Classification              Text               NaN
# 44                   Regression             price               NaN
# 45                   Regression               cnt               NaN
# 46                   Regression              medv               NaN
# 47                   Regression          strength               NaN
# 48                   Regression             Price               NaN
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area               NaN
# 51                   Regression         Gold_T+22               NaN
# 52                   Regression         SalePrice               NaN
# 53                   Regression           charges               NaN
# 54                   Regression               PPE               NaN
# 55                   Regression    traffic_volume               NaN
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %% [markdown]
# ## Loading the Diabetes Dataset

# %%
diabetesDataSet = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %% [markdown]
# ## Explorin the Dataset

# %%
diabetesDataSet.describe()
#Get the statistical summary of the dataset
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# count                        768.000000                        768.000000
# mean                          69.105469                         20.536458
# std                           19.355807                         15.952218
# min                            0.000000                          0.000000
# 25%                           62.000000                          0.000000
# 50%                           72.000000                         23.000000
# 75%                           80.000000                         32.000000
# max                          122.000000                         99.000000
#
#        2-Hour serum insulin (mu U/ml)  \
# count                      768.000000
# mean                        79.799479
# std                        115.244002
# min                          0.000000
# 25%                          0.000000
# 50%                         30.500000
# 75%                        127.250000
# max                        846.000000
#
#        Body mass index (weight in kg/(height in m)^2)  \
# count                                      768.000000
# mean                                        31.992578
# std                                          7.884160
# min                                          0.000000
# 25%                                         27.300000
# 50%                                         32.000000
# 75%                                         36.600000
# max                                         67.100000
#
#        Diabetes pedigree function  Age (years)  Class variable
# count                  768.000000   768.000000      768.000000
# mean                     0.471876    33.240885        0.348958
# std                      0.331329    11.760232        0.476951
# min                      0.078000    21.000000        0.000000
# 25%                      0.243750    24.000000        0.000000
# 50%                      0.372500    29.000000        0.000000
# 75%                      0.626250    41.000000        1.000000
# max                      2.420000    81.000000        1.000000

# %% [markdown]
# ## Get the dimensions of the Dataset

# %%
print("diabetesDataSet.shape -->", diabetesDataSet.shape)
# Print the number of rows (axis 0)
print("Rows  -->", diabetesDataSet.shape[0])
# Print the number of columns (axis 1)
print("Columns -->", diabetesDataSet.shape[1])
# Out:
# diabetesDataSet.shape --> (768, 9)
# Rows  --> 768
# Columns --> 9
