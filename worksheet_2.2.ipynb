# %% [markdown]
# # TASK
# ### Perform the following steps:
# - Load "diabetes" dataset from pycaret library.
# - Train the model using 'lr' and 'ada' classification models.
# - Compare theses 2 models in terms of Accuracy, Recall and Precision.

# %%
import pycaret

# %% [markdown]
# ## Loading the "diabetes" dataset from pycaret library

# %%
from pycaret.datasets import get_data
diabetesDataSet = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %% [markdown]
# ## Set up Classification Environment

# %%
from pycaret.classification import *

# %%
s = setup(data= diabetesDataSet, target= 'Class variable')
# Out:
# <style type="text/css">
# #T_3eaaf_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3eaaf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3eaaf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3eaaf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3eaaf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3eaaf_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3eaaf_row0_col1" class="data row0 col1" >6910</td>
#     </tr>
#     <tr>
#       <th id="T_3eaaf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3eaaf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3eaaf_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_3eaaf_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# ## Training the model using Logistic Regression (LR)

# %%
lrModel = create_model('lr')
# Out:
# <style type="text/css">
# #T_71895_row10_col0, #T_71895_row10_col1, #T_71895_row10_col2, #T_71895_row10_col3, #T_71895_row10_col4, #T_71895_row10_col5, #T_71895_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_71895">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71895_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_71895_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_71895_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_71895_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_71895_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_71895_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_71895_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %% [markdown]
# ## Training the model using AdaBoost

# %%
adaModel = create_model('ada')
# Out:
# <style type="text/css">
# #T_9aa99_row10_col0, #T_9aa99_row10_col1, #T_9aa99_row10_col2, #T_9aa99_row10_col3, #T_9aa99_row10_col4, #T_9aa99_row10_col5, #T_9aa99_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9aa99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9aa99_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9aa99_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9aa99_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9aa99_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9aa99_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9aa99_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9aa99_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %% [markdown]
# ## Comparing the Models

# %%
compare_models(include = ['lr','ada'])
# Out:
# <style type="text/css">
# #T_ead12 th {
#   text-align: left;
# }
# #T_ead12_row0_col0, #T_ead12_row0_col3, #T_ead12_row0_col5, #T_ead12_row0_col6, #T_ead12_row1_col0, #T_ead12_row1_col1, #T_ead12_row1_col2, #T_ead12_row1_col4, #T_ead12_row1_col7 {
#   text-align: left;
# }
# #T_ead12_row0_col1, #T_ead12_row0_col2, #T_ead12_row0_col4, #T_ead12_row0_col7, #T_ead12_row1_col3, #T_ead12_row1_col5, #T_ead12_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ead12_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_ead12_row1_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ead12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ead12_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ead12_level0_col1" class="col_heading level0 col1" >Accuracy</th>
# ...
